# %% [markdown]
# # Loading in our data from main.ipynb to build the initial model

# %% [markdown]
# ### Loading the data

# %%
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

with open("prepared_data.pkl", "rb") as f:
    data = pickle.load(f)

X_train = data["X_train"]
X_val = data["X_val"]
X_test = data["X_test"]
y_train = data["y_train"]
y_val = data["y_val"]
y_test = data["y_test"]
num_classes = data["num_classes"]

# %% [markdown]
# ### Data Normalization

# %%
X_train = X_train.astype("float32") / 255.0
X_val   = X_val.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

# %% [markdown]
# ### Building the model

# %%
def leNet_model_iteration2(num_classes):
    model = Sequential()
    model.add(Conv2D(64, (5,5), activation='relu', input_shape=(28,28,1)))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

model = leNet_model_iteration2(num_classes)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    shear_range=0.1,
    rotation_range=10
)

datagen.fit(X_train)

train_generator = datagen.flow(X_train, y_train, batch_size=50)

batches = datagen.flow(X_train, y_train, batch_size=9)
X_batch, y_batch = next(batches)

fig, axs = plt.subplots(3, 3, figsize=(6, 6))
fig.tight_layout()

for i in range(9):
    r = i // 3
    c = i % 3
    axs[r, c].imshow(X_batch[i])
    axs[r, c].axis('off')

plt.suptitle('Augmented Training Images', fontsize=14)
plt.show()

# %% [markdown]
# ### Training the model

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(X_train) // 50,
    epochs=30,
    batch_size=50,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.2150 - loss: 2.5086 - val_accuracy: 0.3457 - val_loss: 2.1224
# Epoch 2/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.3290 - loss: 2.2077 - val_accuracy: 0.3954 - val_loss: 1.9841
# Epoch 3/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.3688 - loss: 2.0914 - val_accuracy: 0.4099 - val_loss: 1.9036
# Epoch 4/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.3866 - loss: 2.0185 - val_accuracy: 0.4404 - val_loss: 1.8431
# Epoch 5/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4008 - loss: 1.9698 - val_accuracy: 0.4523 - val_loss: 1.8001
# Epoch 6/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.4130 - loss: 1.9195 - val_accuracy: 0.4716 - val_loss: 1.7617
# Epoch 7/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4268 - loss: 1.8920 - val_accuracy: 0.4749 - val_loss: 1.7355
# Epoch 8/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4375 - loss: 1.8477 - val_accuracy: 0.4802 - val_loss: 1.7005
# Epoch 9/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4497 - loss: 1.8232 - val_accuracy: 0.4862 - val_loss: 1.6771
# Epoch 10/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4581 - loss: 1.8077 - val_accuracy: 0.4916 - val_loss: 1.6571
# Epoch 11/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - accuracy: 0.4645 - loss: 1.7753 - val_accuracy: 0.5048 - val_loss: 1.6314
# Epoch 12/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4718 - loss: 1.7502 - val_accuracy: 0.4967 - val_loss: 1.6319
# Epoch 13/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4750 - loss: 1.7300 - val_accuracy: 0.5143 - val_loss: 1.6101
# Epoch 14/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4834 - loss: 1.7091 - val_accuracy: 0.5112 - val_loss: 1.5966
# Epoch 15/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.4866 - loss: 1.6874 - val_accuracy: 0.5149 - val_loss: 1.5948
# Epoch 16/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.4874 - loss: 1.6781 - val_accuracy: 0.5209 - val_loss: 1.5617
# Epoch 17/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4930 - loss: 1.6526 - val_accuracy: 0.5202 - val_loss: 1.5755
# Epoch 18/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4932 - loss: 1.6587 - val_accuracy: 0.5336 - val_loss: 1.5426
# Epoch 19/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.5010 - loss: 1.6305 - val_accuracy: 0.5382 - val_loss: 1.5315
# Epoch 20/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.5071 - loss: 1.6188 - val_accuracy: 0.5369 - val_loss: 1.5369
# Epoch 21/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.5105 - loss: 1.5964 - val_accuracy: 0.5420 - val_loss: 1.5220
# Epoch 22/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5135 - loss: 1.6065 - val_accuracy: 0.5418 - val_loss: 1.5185
# Epoch 23/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.5176 - loss: 1.5846 - val_accuracy: 0.5415 - val_loss: 1.5255
# Epoch 24/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.5193 - loss: 1.5653 - val_accuracy: 0.5431 - val_loss: 1.5174
# Epoch 25/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.5243 - loss: 1.5698 - val_accuracy: 0.5382 - val_loss: 1.5137
# Epoch 26/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.5224 - loss: 1.5568 - val_accuracy: 0.5402 - val_loss: 1.4985
# Epoch 27/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5209 - loss: 1.5636 - val_accuracy: 0.5510 - val_loss: 1.4988
# Epoch 28/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5305 - loss: 1.5417 - val_accuracy: 0.5371 - val_loss: 1.5215
# Epoch 29/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5297 - loss: 1.5374 - val_accuracy: 0.5490 - val_loss: 1.4884
# Epoch 30/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.5369 - loss: 1.5123 - val_accuracy: 0.5549 - val_loss: 1.4845

# %% [markdown]
# ### Evaluating the model

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss:", score[0])
print("Test Accuracy:", score[1])

plt.figure(figsize=(12,5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training', 'validation'])
plt.title("Loss")
plt.xlabel("epoch")

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'])
plt.title("Accuracy")
plt.xlabel("epoch")

plt.tight_layout()
plt.show()
# Out:
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6321 - loss: 1.1535
# Test Loss: 1.4532737731933594
# Test Accuracy: 0.5634065866470337
