# %% [markdown]
# # Loading in our data from main.ipynb to build the deeper model

# %% [markdown]
# ### Loading the data

# %%
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np

with open("prepared_data.pkl", "rb") as f:
    data = pickle.load(f)

X_train = data["X_train"]
X_val = data["X_val"]
X_test = data["X_test"]
y_train = data["y_train"]
y_val = data["y_val"]
y_test = data["y_test"]
class_weights_dict = data["class_weights"]
num_classes = data["num_classes"]

# %% [markdown]
# ### Data Augmentation

# %%
X_train = X_train.astype("float32") / 255.0
X_val   = X_val.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

# %% [markdown]
# ### Building the model

# %%
def build_cnn(num_classes):
    model = Sequential([
        Conv2D(64, (3,3), padding='same', activation='relu', input_shape=(32,32,3)),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.25),

        Conv2D(128, (3,3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.25),

        Conv2D(256, (3,3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.25),

        Flatten(),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),

        Dense(num_classes, activation='softmax')
    ])

    return model

# %% [markdown]
# ### Parameters

# %%
model = build_cnn(num_classes)

optimizer = Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │     1,048,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 24)             │         6,168 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,428,632 (5.45 MB)
#  Trainable params: 1,427,224 (5.44 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %% [markdown]
# ### Data augmentation

# %%
batch_size = 64
epochs = 40

# %% [markdown]
# ### Training the model

# %%
print("Training the model...")

history = model.fit(
    X_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weights_dict,
    shuffle=True,
    verbose=1
)

print("Evaluating on test set...")

test_loss, test_accuracy = model.evaluate(
    X_test,
    y_test,
    batch_size=batch_size,
    verbose=1
)

print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
# Out:
# Training the model...
# Epoch 1/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.2300 - loss: 2.4452 - val_accuracy: 0.4053 - val_loss: 1.9190
# Epoch 2/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4242 - loss: 1.5891 - val_accuracy: 0.4947 - val_loss: 1.6686
# Epoch 3/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.4980 - loss: 1.3753 - val_accuracy: 0.5431 - val_loss: 1.4917
# Epoch 4/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5480 - loss: 1.2309 - val_accuracy: 0.4635 - val_loss: 1.6298
# Epoch 5/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.5758 - loss: 1.1418 - val_accuracy: 0.5668 - val_loss: 1.3817
# Epoch 6/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5935 - loss: 1.0620 - val_accuracy: 0.5226 - val_loss: 1.5970
# Epoch 7/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6212 - loss: 0.9824 - val_accuracy: 0.5785 - val_loss: 1.3683
# Epoch 8/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6294 - loss: 0.9301 - val_accuracy: 0.5855 - val_loss: 1.3063
# Epoch 9/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6555 - loss: 0.8576 - val_accuracy: 0.6097 - val_loss: 1.2227
# Epoch 10/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6727 - loss: 0.8063 - val_accuracy: 0.6204 - val_loss: 1.1909
# Epoch 11/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.6770 - loss: 0.7779 - val_accuracy: 0.6002 - val_loss: 1.3000
# Epoch 12/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6894 - loss: 0.7219 - val_accuracy: 0.6018 - val_loss: 1.3144
# Epoch 13/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7116 - loss: 0.6734 - val_accuracy: 0.6635 - val_loss: 1.0366
# Epoch 14/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7205 - loss: 0.6310 - val_accuracy: 0.6585 - val_loss: 1.0969
# Epoch 15/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7289 - loss: 0.6082 - val_accuracy: 0.6651 - val_loss: 1.0799
# Epoch 16/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7370 - loss: 0.5764 - val_accuracy: 0.6782 - val_loss: 1.0206
# Epoch 17/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7417 - loss: 0.5678 - val_accuracy: 0.6549 - val_loss: 1.1269
# Epoch 18/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7500 - loss: 0.5411 - val_accuracy: 0.6734 - val_loss: 1.0687
# Epoch 19/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7595 - loss: 0.5109 - val_accuracy: 0.5695 - val_loss: 1.5715
# Epoch 20/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7556 - loss: 0.5046 - val_accuracy: 0.6721 - val_loss: 1.0832
# Epoch 21/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7680 - loss: 0.4871 - val_accuracy: 0.6624 - val_loss: 1.0819
# Epoch 22/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7688 - loss: 0.4807 - val_accuracy: 0.6884 - val_loss: 1.0385
# Epoch 23/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7785 - loss: 0.4500 - val_accuracy: 0.6692 - val_loss: 1.0956
# Epoch 24/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7850 - loss: 0.4416 - val_accuracy: 0.6901 - val_loss: 1.0000
# Epoch 25/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7871 - loss: 0.4354 - val_accuracy: 0.7044 - val_loss: 0.9996
# Epoch 26/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7957 - loss: 0.4060 - val_accuracy: 0.7026 - val_loss: 1.0125
# Epoch 27/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7958 - loss: 0.4056 - val_accuracy: 0.6967 - val_loss: 1.0269
# Epoch 28/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8061 - loss: 0.3904 - val_accuracy: 0.7048 - val_loss: 1.0202
# Epoch 29/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8052 - loss: 0.3850 - val_accuracy: 0.6901 - val_loss: 1.0879
# Epoch 30/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8046 - loss: 0.3849 - val_accuracy: 0.7088 - val_loss: 1.0326
# Epoch 31/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8103 - loss: 0.3760 - val_accuracy: 0.6978 - val_loss: 1.0311
# Epoch 32/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8129 - loss: 0.3678 - val_accuracy: 0.6969 - val_loss: 1.1360
# Epoch 33/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8145 - loss: 0.3561 - val_accuracy: 0.6820 - val_loss: 1.1155
# Epoch 34/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8196 - loss: 0.3482 - val_accuracy: 0.7079 - val_loss: 1.0173
# Epoch 35/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8218 - loss: 0.3501 - val_accuracy: 0.6956 - val_loss: 1.1108
# Epoch 36/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8292 - loss: 0.3320 - val_accuracy: 0.7029 - val_loss: 1.0236
# Epoch 37/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.8313 - loss: 0.3282 - val_accuracy: 0.7048 - val_loss: 1.0167
# Epoch 38/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8290 - loss: 0.3226 - val_accuracy: 0.6833 - val_loss: 1.2565
# Epoch 39/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8348 - loss: 0.3247 - val_accuracy: 0.7066 - val_loss: 1.0713
# Epoch 40/40
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8348 - loss: 0.3155 - val_accuracy: 0.7180 - val_loss: 1.0147
# Evaluating on test set...
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7645 - loss: 0.7362
#
# Test Loss: 1.0162
# Test Accuracy: 0.7193 (71.93%)

# %% [markdown]
# ### Plotting Training History

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# loss
ax1.plot(history.history['loss'], label='Training Loss', linewidth=2, alpha=0.8)
ax1.plot(history.history['val_loss'], label='Validation Loss', linewidth=2, alpha=0.8)
ax1.set_title('Model Loss Over Epochs', fontsize=14, fontweight='bold')
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Loss', fontsize=12)
ax1.legend(fontsize=11)
ax1.grid(True, alpha=0.3)

# accuracy
ax2.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2, alpha=0.8)
ax2.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2, alpha=0.8)
ax2.set_title('Model Accuracy Over Epochs', fontsize=14, fontweight='bold')
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Accuracy', fontsize=12)
ax2.legend(fontsize=11)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Testing with images

# %%
class_names = [f"Class {i}" for i in range(num_classes)]

num_samples = 4
random_indices = np.random.choice(len(X_test), size=num_samples, replace=False)

plt.figure(figsize=(15, 5))

for i, idx in enumerate(random_indices):
    image = X_test[idx]
    true_label = y_test[idx]

    pred_probs = model.predict(np.expand_dims(image, axis=0))
    pred_label = np.argmax(pred_probs)

    plt.subplot(1, num_samples, i+1)
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"True: {class_names[true_label]}\nPred: {class_names[pred_label]}")

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
