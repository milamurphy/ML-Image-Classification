# %% [markdown]
# # Loading in our data from main.ipynb to build the deeper model

# %% [markdown]
# ### Loading the data

# %%
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, Sequential
import matplotlib.pyplot as plt
import numpy as np

with open("prepared_data.pkl", "rb") as f:
    data = pickle.load(f)

X_train = data["X_train"]
X_val = data["X_val"]
X_test = data["X_test"]
y_train = data["y_train"]
y_val = data["y_val"]
y_test = data["y_test"]
class_weights_dict = data["class_weights"]
num_classes = data["num_classes"]

# %% [markdown]
# ### Data Normalization

# %%
X_train = X_train.astype("float32") / 255.0
X_val   = X_val.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

# %% [markdown]
# ### Building the model

# %%
def build_cnn(num_classes):
    model = Sequential([
        layers.RandomFlip("horizontal", input_shape=(32,32,3)),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),

        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)),
        BatchNormalization(),
        MaxPooling2D(2,2),

        Conv2D(64, (3,3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.3),

        Conv2D(128, (3,3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(2,2),

        Flatten(),

        Dense(256, activation='relu'),
        Dropout(0.4),

        Dense(num_classes, activation='softmax')
    ])

    return model

# %% [markdown]
# ### Parameters

# %%
model = build_cnn(num_classes)

optimizer = Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 24)             │         6,168 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 624,856 (2.38 MB)
#  Trainable params: 624,408 (2.38 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ### Data augmentation

# %%
batch_size = 64
epochs = 50

# %% [markdown]
# ### Training the model

# %%
print("Training the model...")

history = model.fit(
    X_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weights_dict,
    shuffle=True,
    verbose=1
)

print("Evaluating on test set...")

test_loss, test_accuracy = model.evaluate(
    X_test,
    y_test,
    batch_size=batch_size,
    verbose=1
)

print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
# Out:
# Training the model...
# Epoch 1/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.2419 - loss: 2.3067 - val_accuracy: 0.3732 - val_loss: 2.0720
# Epoch 2/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3602 - loss: 1.7915 - val_accuracy: 0.4105 - val_loss: 1.9608
# Epoch 3/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4034 - loss: 1.6622 - val_accuracy: 0.4198 - val_loss: 1.8790
# Epoch 4/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4403 - loss: 1.5361 - val_accuracy: 0.4209 - val_loss: 1.8819
# Epoch 5/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4757 - loss: 1.4314 - val_accuracy: 0.5418 - val_loss: 1.5332
# Epoch 6/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4893 - loss: 1.3664 - val_accuracy: 0.5123 - val_loss: 1.5853
# Epoch 7/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5080 - loss: 1.2979 - val_accuracy: 0.5380 - val_loss: 1.4774
# Epoch 8/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5355 - loss: 1.2444 - val_accuracy: 0.5771 - val_loss: 1.3430
# Epoch 9/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5607 - loss: 1.1587 - val_accuracy: 0.5763 - val_loss: 1.3076
# Epoch 10/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5654 - loss: 1.1412 - val_accuracy: 0.6114 - val_loss: 1.2539
# Epoch 11/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5812 - loss: 1.0777 - val_accuracy: 0.6018 - val_loss: 1.2579
# Epoch 12/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6006 - loss: 1.0317 - val_accuracy: 0.5857 - val_loss: 1.3294
# Epoch 13/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6084 - loss: 0.9842 - val_accuracy: 0.6009 - val_loss: 1.2468
# Epoch 14/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6190 - loss: 0.9487 - val_accuracy: 0.5932 - val_loss: 1.2827
# Epoch 15/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6327 - loss: 0.8940 - val_accuracy: 0.6042 - val_loss: 1.3872
# Epoch 16/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6392 - loss: 0.8701 - val_accuracy: 0.6136 - val_loss: 1.2335
# Epoch 17/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6465 - loss: 0.8431 - val_accuracy: 0.6202 - val_loss: 1.2752
# Epoch 18/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6601 - loss: 0.8018 - val_accuracy: 0.6352 - val_loss: 1.1964
# Epoch 19/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6685 - loss: 0.7670 - val_accuracy: 0.5927 - val_loss: 1.3574
# Epoch 20/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6723 - loss: 0.7474 - val_accuracy: 0.6048 - val_loss: 1.2970
# Epoch 21/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6806 - loss: 0.7254 - val_accuracy: 0.6299 - val_loss: 1.3067
# Epoch 22/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7012 - loss: 0.6740 - val_accuracy: 0.6136 - val_loss: 1.4032
# Epoch 23/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7083 - loss: 0.6576 - val_accuracy: 0.6440 - val_loss: 1.3470
# Epoch 24/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7061 - loss: 0.6522 - val_accuracy: 0.6226 - val_loss: 1.4154
# Epoch 25/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7118 - loss: 0.6391 - val_accuracy: 0.6481 - val_loss: 1.2356
# Epoch 26/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7247 - loss: 0.5922 - val_accuracy: 0.6492 - val_loss: 1.2917
# Epoch 27/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7278 - loss: 0.5846 - val_accuracy: 0.6541 - val_loss: 1.2758
# Epoch 28/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7352 - loss: 0.5753 - val_accuracy: 0.6086 - val_loss: 1.3953
# Epoch 29/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7401 - loss: 0.5469 - val_accuracy: 0.6497 - val_loss: 1.3063
# Epoch 30/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7449 - loss: 0.5423 - val_accuracy: 0.6677 - val_loss: 1.2008
# Epoch 31/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7549 - loss: 0.5191 - val_accuracy: 0.6330 - val_loss: 1.4084
# Epoch 32/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7550 - loss: 0.5131 - val_accuracy: 0.6703 - val_loss: 1.3157
# Epoch 33/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7658 - loss: 0.4963 - val_accuracy: 0.6488 - val_loss: 1.3114
# Epoch 34/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7687 - loss: 0.4919 - val_accuracy: 0.6723 - val_loss: 1.2309
# Epoch 35/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7755 - loss: 0.4769 - val_accuracy: 0.6659 - val_loss: 1.2740
# Epoch 36/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7686 - loss: 0.4789 - val_accuracy: 0.6591 - val_loss: 1.3494
# Epoch 37/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7783 - loss: 0.4571 - val_accuracy: 0.6668 - val_loss: 1.3536
# Epoch 38/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7799 - loss: 0.4507 - val_accuracy: 0.6523 - val_loss: 1.3738
# Epoch 39/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7851 - loss: 0.4442 - val_accuracy: 0.6679 - val_loss: 1.2746
# Epoch 40/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7812 - loss: 0.4419 - val_accuracy: 0.6596 - val_loss: 1.4408
# Epoch 41/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7888 - loss: 0.4286 - val_accuracy: 0.6510 - val_loss: 1.3815
# Epoch 42/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7951 - loss: 0.4079 - val_accuracy: 0.6600 - val_loss: 1.2986
# Epoch 43/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7925 - loss: 0.4239 - val_accuracy: 0.6769 - val_loss: 1.3763
# Epoch 44/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8050 - loss: 0.3932 - val_accuracy: 0.6802 - val_loss: 1.3010
# Epoch 45/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8086 - loss: 0.3947 - val_accuracy: 0.6600 - val_loss: 1.3501
# Epoch 46/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8106 - loss: 0.3840 - val_accuracy: 0.6789 - val_loss: 1.4236
# Epoch 47/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8124 - loss: 0.3804 - val_accuracy: 0.6745 - val_loss: 1.3464
# Epoch 48/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8132 - loss: 0.3761 - val_accuracy: 0.6859 - val_loss: 1.4245
# Epoch 49/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8143 - loss: 0.3725 - val_accuracy: 0.6719 - val_loss: 1.3040
# Epoch 50/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8067 - loss: 0.3911 - val_accuracy: 0.6820 - val_loss: 1.3548
# Evaluating on test set...
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7257 - loss: 0.9441
#
# Test Loss: 1.3153
# Test Accuracy: 0.6822 (68.22%)

# %% [markdown]
# ### Plotting Training History

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# loss
ax1.plot(history.history['loss'], label='Training Loss', linewidth=2, alpha=0.8)
ax1.plot(history.history['val_loss'], label='Validation Loss', linewidth=2, alpha=0.8)
ax1.set_title('Model Loss Over Epochs', fontsize=14, fontweight='bold')
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Loss', fontsize=12)
ax1.legend(fontsize=11)
ax1.grid(True, alpha=0.3)

# accuracy
ax2.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2, alpha=0.8)
ax2.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2, alpha=0.8)
ax2.set_title('Model Accuracy Over Epochs', fontsize=14, fontweight='bold')
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Accuracy', fontsize=12)
ax2.legend(fontsize=11)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Testing with images

# %%
class_names = [f"Class {i}" for i in range(num_classes)]

num_samples = 4
random_indices = np.random.choice(len(X_test), size=num_samples, replace=False)

plt.figure(figsize=(15, 5))

for i, idx in enumerate(random_indices):
    image = X_test[idx]
    true_label = y_test[idx]

    pred_probs = model.predict(np.expand_dims(image, axis=0))
    pred_label = np.argmax(pred_probs)

    plt.subplot(1, num_samples, i+1)
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"True: {class_names[true_label]}\nPred: {class_names[pred_label]}")

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
