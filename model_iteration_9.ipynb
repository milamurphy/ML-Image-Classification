# %% [markdown]
# # Loading in our data from main.ipynb to build the initial model

# %% [markdown]
# ### Loading the data

# %%
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np

with open("prepared_data.pkl", "rb") as f:
    data = pickle.load(f)

X_train = data["X_train"]
X_val = data["X_val"]
X_test = data["X_test"]
y_train = data["y_train"]
y_val = data["y_val"]
y_test = data["y_test"]
class_weights_dict = data["class_weights"]
num_classes = data["num_classes"]

# %% [markdown]
# ### Data Normalization

# %%
X_train = X_train.astype("float32") / 255.0
X_val   = X_val.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

# %% [markdown]
# ### Building the model

# %%
def leNet_model_iteration9(num_classes):
    model = Sequential()

    model.add(Conv2D(64, (3,3), padding='same', activation='relu', input_shape=(32,32,3)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
batch_size = 64
epochs = 50

def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.image.resize_with_crop_or_pad(image, 36, 36)
    image = tf.image.random_crop(image, [32, 32, 3])

    return image, label


train_ds = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(10000)
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_ds = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

fig, axs = plt.subplots(3, 3, figsize=(6, 6))
fig.tight_layout()

for i in range(9):
    r = i // 3
    c = i % 3
    axs[r, c].imshow(X_batch[i])
    axs[r, c].axis('off')

plt.suptitle('Augmented Training Images', fontsize=14)
plt.show()

# %% [markdown]
# ### Training the model

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-7,
    verbose=1
)

model = leNet_model_iteration9(num_classes)

history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=val_ds,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights_dict,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 42s 41ms/step - accuracy: 0.2030 - loss: 2.5813 - val_accuracy: 0.3473 - val_loss: 2.0624 - learning_rate: 0.0010
# Epoch 2/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.3719 - loss: 1.7645 - val_accuracy: 0.3780 - val_loss: 2.1672 - learning_rate: 0.0010
# Epoch 3/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.4634 - loss: 1.4973 - val_accuracy: 0.5299 - val_loss: 1.4891 - learning_rate: 0.0010
# Epoch 4/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.5372 - loss: 1.2934 - val_accuracy: 0.5767 - val_loss: 1.3503 - learning_rate: 0.0010
# Epoch 5/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.5861 - loss: 1.1626 - val_accuracy: 0.6468 - val_loss: 1.1162 - learning_rate: 0.0010
# Epoch 6/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6199 - loss: 1.0557 - val_accuracy: 0.6382 - val_loss: 1.1339 - learning_rate: 0.0010
# Epoch 7/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6456 - loss: 0.9877 - val_accuracy: 0.6492 - val_loss: 1.0942 - learning_rate: 0.0010
# Epoch 8/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6596 - loss: 0.9313 - val_accuracy: 0.6611 - val_loss: 1.0507 - learning_rate: 0.0010
# Epoch 9/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6802 - loss: 0.8779 - val_accuracy: 0.6987 - val_loss: 0.9320 - learning_rate: 0.0010
# Epoch 10/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.6980 - loss: 0.8152 - val_accuracy: 0.7240 - val_loss: 0.8752 - learning_rate: 0.0010
# Epoch 11/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.7073 - loss: 0.7828 - val_accuracy: 0.6993 - val_loss: 0.9493 - learning_rate: 0.0010
# Epoch 12/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.7147 - loss: 0.7577 - val_accuracy: 0.7288 - val_loss: 0.8460 - learning_rate: 0.0010
# Epoch 13/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7231 - loss: 0.7401 - val_accuracy: 0.7167 - val_loss: 0.8718 - learning_rate: 0.0010
# Epoch 14/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7325 - loss: 0.6967 - val_accuracy: 0.7358 - val_loss: 0.8127 - learning_rate: 0.0010
# Epoch 15/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7480 - loss: 0.6539 - val_accuracy: 0.7602 - val_loss: 0.7393 - learning_rate: 0.0010
# Epoch 16/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.7512 - loss: 0.6367 - val_accuracy: 0.6620 - val_loss: 1.1516 - learning_rate: 0.0010
# Epoch 17/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.7590 - loss: 0.6121 - val_accuracy: 0.7620 - val_loss: 0.7426 - learning_rate: 0.0010
# Epoch 18/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.7657 - loss: 0.5981 - val_accuracy: 0.7716 - val_loss: 0.7118 - learning_rate: 0.0010
# Epoch 19/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.7712 - loss: 0.5687 - val_accuracy: 0.7833 - val_loss: 0.6884 - learning_rate: 0.0010
# Epoch 20/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7801 - loss: 0.5477 - val_accuracy: 0.7760 - val_loss: 0.6960 - learning_rate: 0.0010
# Epoch 21/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7874 - loss: 0.5245 - val_accuracy: 0.7846 - val_loss: 0.6808 - learning_rate: 0.0010
# Epoch 22/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7908 - loss: 0.5142 - val_accuracy: 0.7662 - val_loss: 0.7512 - learning_rate: 0.0010
# Epoch 23/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7948 - loss: 0.5012 - val_accuracy: 0.7681 - val_loss: 0.7401 - learning_rate: 0.0010
# Epoch 24/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7951 - loss: 0.5025 - val_accuracy: 0.7859 - val_loss: 0.6695 - learning_rate: 0.0010
# Epoch 25/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8069 - loss: 0.4718 - val_accuracy: 0.7747 - val_loss: 0.6981 - learning_rate: 0.0010
# Epoch 26/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8086 - loss: 0.4540 - val_accuracy: 0.7835 - val_loss: 0.6732 - learning_rate: 0.0010
# Epoch 27/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8121 - loss: 0.4453 - val_accuracy: 0.7785 - val_loss: 0.6951 - learning_rate: 0.0010
# Epoch 28/50
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8226 - loss: 0.4163
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8226 - loss: 0.4163 - val_accuracy: 0.7829 - val_loss: 0.6890 - learning_rate: 0.0010
# Epoch 29/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8322 - loss: 0.3930 - val_accuracy: 0.8101 - val_loss: 0.5996 - learning_rate: 5.0000e-04
# Epoch 30/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8426 - loss: 0.3521 - val_accuracy: 0.8207 - val_loss: 0.6004 - learning_rate: 5.0000e-04
# Epoch 31/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.8491 - loss: 0.3379 - val_accuracy: 0.8180 - val_loss: 0.6021 - learning_rate: 5.0000e-04
# Epoch 32/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.8568 - loss: 0.3216 - val_accuracy: 0.8191 - val_loss: 0.5968 - learning_rate: 5.0000e-04
# Epoch 33/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8594 - loss: 0.3124 - val_accuracy: 0.8092 - val_loss: 0.6196 - learning_rate: 5.0000e-04
# Epoch 34/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8619 - loss: 0.3056 - val_accuracy: 0.8160 - val_loss: 0.6171 - learning_rate: 5.0000e-04
# Epoch 35/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.8652 - loss: 0.2922 - val_accuracy: 0.8158 - val_loss: 0.6153 - learning_rate: 5.0000e-04
# Epoch 36/50
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8657 - loss: 0.2967
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.8657 - loss: 0.2967 - val_accuracy: 0.8154 - val_loss: 0.6239 - learning_rate: 5.0000e-04
# Epoch 37/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.8752 - loss: 0.2667 - val_accuracy: 0.8233 - val_loss: 0.6027 - learning_rate: 2.5000e-04
# Epoch 38/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.8836 - loss: 0.2465 - val_accuracy: 0.8240 - val_loss: 0.5870 - learning_rate: 2.5000e-04
# Epoch 39/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8835 - loss: 0.2468 - val_accuracy: 0.8218 - val_loss: 0.6059 - learning_rate: 2.5000e-04
# Epoch 40/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8854 - loss: 0.2355 - val_accuracy: 0.8290 - val_loss: 0.5881 - learning_rate: 2.5000e-04
# Epoch 41/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8902 - loss: 0.2291 - val_accuracy: 0.8209 - val_loss: 0.6118 - learning_rate: 2.5000e-04
# Epoch 42/50
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8885 - loss: 0.2286
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8885 - loss: 0.2285 - val_accuracy: 0.8279 - val_loss: 0.5957 - learning_rate: 2.5000e-04
# Epoch 43/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8913 - loss: 0.2209 - val_accuracy: 0.8330 - val_loss: 0.5831 - learning_rate: 1.2500e-04
# Epoch 44/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8965 - loss: 0.2117 - val_accuracy: 0.8347 - val_loss: 0.5858 - learning_rate: 1.2500e-04
# Epoch 45/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8973 - loss: 0.2048 - val_accuracy: 0.8352 - val_loss: 0.5831 - learning_rate: 1.2500e-04
# Epoch 46/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8997 - loss: 0.1982 - val_accuracy: 0.8345 - val_loss: 0.5874 - learning_rate: 1.2500e-04
# Epoch 47/50
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9035 - loss: 0.1950
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9034 - loss: 0.1950 - val_accuracy: 0.8369 - val_loss: 0.5838 - learning_rate: 1.2500e-04
# Epoch 48/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9031 - loss: 0.1913 - val_accuracy: 0.8356 - val_loss: 0.5846 - learning_rate: 6.2500e-05
# Epoch 49/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9029 - loss: 0.1951 - val_accuracy: 0.8382 - val_loss: 0.5825 - learning_rate: 6.2500e-05
# Epoch 50/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.9069 - loss: 0.1844 - val_accuracy: 0.8385 - val_loss: 0.5860 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 49.

# %% [markdown]
# ### Evaluating the model

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss:", score[0])
print("Test Accuracy:", score[1])

plt.figure(figsize=(12,5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training', 'validation'])
plt.title("Loss")
plt.xlabel("epoch")

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'])
plt.title("Accuracy")
plt.xlabel("epoch")

plt.tight_layout()
plt.show()
# Out:
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8643 - loss: 0.4374
# Test Loss: 0.60213702917099
# Test Accuracy: 0.8323076963424683

# %%
# We referenced ChatGPT to help print out images from out dataset
class_names = [f"Class {i}" for i in range(num_classes)]

num_samples = 4
random_indices = np.random.choice(len(X_test), size=num_samples, replace=False)

plt.figure(figsize=(15, 5))

for i, idx in enumerate(random_indices):
    image = X_test[idx]
    true_label = y_test[idx]

    pred_probs = model.predict(np.expand_dims(image, axis=0))
    pred_label = np.argmax(pred_probs)

    plt.subplot(1, num_samples, i+1)
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"True: {class_names[true_label]}\nPred: {class_names[pred_label]}")

plt.show()
