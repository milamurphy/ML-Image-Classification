# %% [markdown]
# # Loading in our data from main.ipynb to build the initial model

# %% [markdown]
# ### Loading the data

# %%
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

with open("prepared_data.pkl", "rb") as f:
    data = pickle.load(f)

X_train = data["X_train"]
X_val = data["X_val"]
X_test = data["X_test"]
y_train = data["y_train"]
y_val = data["y_val"]
y_test = data["y_test"]
# class_weights_dict = data["class_weights"]
num_classes = data["num_classes"]

# %% [markdown]
# ### Data Normalization

# %%
X_train = X_train.astype("float32") / 255.0
X_val   = X_val.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

# %% [markdown]
# ### Building the model

# %%
def leNet_model_iteration1(num_classes):
    model = Sequential()
    model.add(Conv2D(64, (5,5), activation='relu', input_shape=(28,28,1)))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

model = leNet_model_iteration1(num_classes)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    shear_range=0.1,
    rotation_range=10
)

datagen.fit(X_train)

train_generator = datagen.flow(X_train, y_train, batch_size=50)

batches = datagen.flow(X_train, y_train, batch_size=9)
X_batch, y_batch = next(batches)

fig, axs = plt.subplots(3, 3, figsize=(6, 6))
fig.tight_layout()

for i in range(9):
    r = i // 3
    c = i % 3
    axs[r, c].imshow(X_batch[i])
    axs[r, c].axis('off')

plt.suptitle('Augmented Training Images', fontsize=14)
plt.show()

# %% [markdown]
# ### Training the model

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(X_train) // 50,
    epochs=30,
    batch_size=20,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.2196 - loss: 2.5010 - val_accuracy: 0.3626 - val_loss: 2.1007
# Epoch 2/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.3245 - loss: 2.2022 - val_accuracy: 0.3840 - val_loss: 2.0234
# Epoch 3/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.3608 - loss: 2.1051 - val_accuracy: 0.3938 - val_loss: 1.9889
# Epoch 4/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.3853 - loss: 2.0354 - val_accuracy: 0.4479 - val_loss: 1.8359
# Epoch 5/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4055 - loss: 1.9649 - val_accuracy: 0.4622 - val_loss: 1.7821
# Epoch 6/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4168 - loss: 1.9230 - val_accuracy: 0.4609 - val_loss: 1.7845
# Epoch 7/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4295 - loss: 1.8860 - val_accuracy: 0.4813 - val_loss: 1.7212
# Epoch 8/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4397 - loss: 1.8512 - val_accuracy: 0.4866 - val_loss: 1.6978
# Epoch 9/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4503 - loss: 1.8329 - val_accuracy: 0.4886 - val_loss: 1.6974
# Epoch 10/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4588 - loss: 1.7864 - val_accuracy: 0.4991 - val_loss: 1.6587
# Epoch 11/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4582 - loss: 1.7752 - val_accuracy: 0.5097 - val_loss: 1.6284
# Epoch 12/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4726 - loss: 1.7487 - val_accuracy: 0.5103 - val_loss: 1.6190
# Epoch 13/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4730 - loss: 1.7386 - val_accuracy: 0.5101 - val_loss: 1.6086
# Epoch 14/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4761 - loss: 1.7202 - val_accuracy: 0.5229 - val_loss: 1.5887
# Epoch 15/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4907 - loss: 1.6929 - val_accuracy: 0.5297 - val_loss: 1.5920
# Epoch 16/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4877 - loss: 1.6956 - val_accuracy: 0.5312 - val_loss: 1.5884
# Epoch 17/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4869 - loss: 1.6806 - val_accuracy: 0.5092 - val_loss: 1.6147
# Epoch 18/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4989 - loss: 1.6443 - val_accuracy: 0.5400 - val_loss: 1.5488
# Epoch 19/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4961 - loss: 1.6352 - val_accuracy: 0.5411 - val_loss: 1.5482
# Epoch 20/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.4993 - loss: 1.6370 - val_accuracy: 0.5470 - val_loss: 1.5332
# Epoch 21/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5047 - loss: 1.6222 - val_accuracy: 0.5365 - val_loss: 1.5329
# Epoch 22/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.5110 - loss: 1.6040 - val_accuracy: 0.5330 - val_loss: 1.5651
# Epoch 23/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5125 - loss: 1.6040 - val_accuracy: 0.5534 - val_loss: 1.5035
# Epoch 24/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5088 - loss: 1.5983 - val_accuracy: 0.5382 - val_loss: 1.5460
# Epoch 25/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5172 - loss: 1.5851 - val_accuracy: 0.5409 - val_loss: 1.5279
# Epoch 26/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.5231 - loss: 1.5711 - val_accuracy: 0.5457 - val_loss: 1.5465
# Epoch 27/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5246 - loss: 1.5598 - val_accuracy: 0.5512 - val_loss: 1.5005
# Epoch 28/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5220 - loss: 1.5520 - val_accuracy: 0.5473 - val_loss: 1.5097
# Epoch 29/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.5257 - loss: 1.5491 - val_accuracy: 0.5495 - val_loss: 1.4999
# Epoch 30/30
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.5292 - loss: 1.5415 - val_accuracy: 0.5484 - val_loss: 1.5279

# %% [markdown]
# ### Evaluating the model

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss:", score[0])
print("Test Accuracy:", score[1])

plt.figure(figsize=(12,5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training', 'validation'])
plt.title("Loss")
plt.xlabel("epoch")

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'])
plt.title("Accuracy")
plt.xlabel("epoch")

plt.tight_layout()
plt.show()
# Out:
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6377 - loss: 1.1532
# Test Loss: 1.4872063398361206
# Test Accuracy: 0.554505467414856
