# %% [markdown]
# # Loading in our data from main.ipynb to build the deeper model

# %% [markdown]
# ### Loading the data

# %%
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np

with open("prepared_data.pkl", "rb") as f:
    data = pickle.load(f)

X_train = data["X_train"]
X_val = data["X_val"]
X_test = data["X_test"]
y_train = data["y_train"]
y_val = data["y_val"]
y_test = data["y_test"]
class_weights_dict = data["class_weights"]
num_classes = data["num_classes"]

# %% [markdown]
# ### Building the model

# %%
def build_cnn(num_classes):
    model = Sequential([
        Conv2D(64, (3,3), padding='same', activation='relu', input_shape=(32,32,3)),
        BatchNormalization(),
        Conv2D(64, (3,3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.25),

        Conv2D(128, (3,3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(128, (3,3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.25),

        Conv2D(256, (3,3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(256, (3,3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.25),

        Flatten(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    return model

# %% [markdown]
# ### Parameters and addressing under/overfitting

# %%
model = build_cnn(num_classes)

optimizer = Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-7,
    verbose=1
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 24)             │        12,312 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,261,016 (12.44 MB)
#  Trainable params: 3,258,200 (12.43 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %% [markdown]
# ### Data augmentation

# %%
batch_size = 64
epochs = 50

def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.image.resize_with_crop_or_pad(image, 36, 36)
    image = tf.image.random_crop(image, [32, 32, 3])
    return image, label

train_ds = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(10000)
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_ds = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ### Training the model

# %%
print("Training the model...")

history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=val_ds,
    class_weight=class_weights_dict,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

print("Evaluating on test set...")

test_loss, test_accuracy = model.evaluate(
    X_test,
    y_test,
    batch_size=batch_size,
    verbose=1
)

print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
# Out:
# Training the model...
# Epoch 1/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 39s 38ms/step - accuracy: 0.2110 - loss: 2.5524 - val_accuracy: 0.3618 - val_loss: 2.1317 - learning_rate: 0.0010
# Epoch 2/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.3728 - loss: 1.8489 - val_accuracy: 0.4334 - val_loss: 1.8043 - learning_rate: 0.0010
# Epoch 3/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.4604 - loss: 1.5086 - val_accuracy: 0.5059 - val_loss: 1.5875 - learning_rate: 0.0010
# Epoch 4/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.5259 - loss: 1.3253 - val_accuracy: 0.5820 - val_loss: 1.3240 - learning_rate: 0.0010
# Epoch 5/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.5764 - loss: 1.1827 - val_accuracy: 0.6092 - val_loss: 1.2441 - learning_rate: 0.0010
# Epoch 6/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.6090 - loss: 1.0870 - val_accuracy: 0.6554 - val_loss: 1.0847 - learning_rate: 0.0010
# Epoch 7/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.6357 - loss: 1.0270 - val_accuracy: 0.6618 - val_loss: 1.0525 - learning_rate: 0.0010
# Epoch 8/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.6481 - loss: 0.9765 - val_accuracy: 0.6716 - val_loss: 1.0074 - learning_rate: 0.0010
# Epoch 9/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.6728 - loss: 0.8990 - val_accuracy: 0.6864 - val_loss: 0.9495 - learning_rate: 0.0010
# Epoch 10/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.6854 - loss: 0.8558 - val_accuracy: 0.6952 - val_loss: 0.9481 - learning_rate: 0.0010
# Epoch 11/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.6931 - loss: 0.8273 - val_accuracy: 0.7160 - val_loss: 0.9018 - learning_rate: 0.0010
# Epoch 12/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7091 - loss: 0.7827 - val_accuracy: 0.7259 - val_loss: 0.8533 - learning_rate: 0.0010
# Epoch 13/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7163 - loss: 0.7527 - val_accuracy: 0.7343 - val_loss: 0.8078 - learning_rate: 0.0010
# Epoch 14/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7284 - loss: 0.7207 - val_accuracy: 0.7486 - val_loss: 0.7840 - learning_rate: 0.0010
# Epoch 15/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7294 - loss: 0.7018 - val_accuracy: 0.7378 - val_loss: 0.8037 - learning_rate: 0.0010
# Epoch 16/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7418 - loss: 0.6691 - val_accuracy: 0.7499 - val_loss: 0.7702 - learning_rate: 0.0010
# Epoch 17/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7532 - loss: 0.6291 - val_accuracy: 0.7558 - val_loss: 0.7708 - learning_rate: 0.0010
# Epoch 18/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7579 - loss: 0.6156 - val_accuracy: 0.7527 - val_loss: 0.7778 - learning_rate: 0.0010
# Epoch 19/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7649 - loss: 0.5935 - val_accuracy: 0.7681 - val_loss: 0.7347 - learning_rate: 0.0010
# Epoch 20/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7681 - loss: 0.5934 - val_accuracy: 0.7677 - val_loss: 0.7315 - learning_rate: 0.0010
# Epoch 21/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7786 - loss: 0.5567 - val_accuracy: 0.7796 - val_loss: 0.6977 - learning_rate: 0.0010
# Epoch 22/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7854 - loss: 0.5386 - val_accuracy: 0.7848 - val_loss: 0.6791 - learning_rate: 0.0010
# Epoch 23/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7844 - loss: 0.5390 - val_accuracy: 0.7767 - val_loss: 0.7212 - learning_rate: 0.0010
# Epoch 24/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7968 - loss: 0.5003 - val_accuracy: 0.7400 - val_loss: 0.8861 - learning_rate: 0.0010
# Epoch 25/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7923 - loss: 0.5031 - val_accuracy: 0.7870 - val_loss: 0.6802 - learning_rate: 0.0010
# Epoch 26/50
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7977 - loss: 0.4825
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7977 - loss: 0.4825 - val_accuracy: 0.7890 - val_loss: 0.6840 - learning_rate: 0.0010
# Epoch 27/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8148 - loss: 0.4301 - val_accuracy: 0.8029 - val_loss: 0.6367 - learning_rate: 5.0000e-04
# Epoch 28/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8350 - loss: 0.3828 - val_accuracy: 0.8132 - val_loss: 0.6278 - learning_rate: 5.0000e-04
# Epoch 29/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8348 - loss: 0.3788 - val_accuracy: 0.8121 - val_loss: 0.6125 - learning_rate: 5.0000e-04
# Epoch 30/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8399 - loss: 0.3624 - val_accuracy: 0.8127 - val_loss: 0.6106 - learning_rate: 5.0000e-04
# Epoch 31/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8474 - loss: 0.3438 - val_accuracy: 0.8187 - val_loss: 0.6131 - learning_rate: 5.0000e-04
# Epoch 32/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8529 - loss: 0.3265 - val_accuracy: 0.8185 - val_loss: 0.6143 - learning_rate: 5.0000e-04
# Epoch 33/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8508 - loss: 0.3296 - val_accuracy: 0.8182 - val_loss: 0.6264 - learning_rate: 5.0000e-04
# Epoch 34/50
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8537 - loss: 0.3200
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8537 - loss: 0.3200 - val_accuracy: 0.8119 - val_loss: 0.6354 - learning_rate: 5.0000e-04
# Epoch 35/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8608 - loss: 0.3000 - val_accuracy: 0.8314 - val_loss: 0.5807 - learning_rate: 2.5000e-04
# Epoch 36/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8690 - loss: 0.2862 - val_accuracy: 0.8248 - val_loss: 0.5844 - learning_rate: 2.5000e-04
# Epoch 37/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8719 - loss: 0.2712 - val_accuracy: 0.8268 - val_loss: 0.5996 - learning_rate: 2.5000e-04
# Epoch 38/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.8680 - loss: 0.2748 - val_accuracy: 0.8308 - val_loss: 0.5992 - learning_rate: 2.5000e-04
# Epoch 39/50
# 637/640 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8795 - loss: 0.2567
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8795 - loss: 0.2567 - val_accuracy: 0.8319 - val_loss: 0.5973 - learning_rate: 2.5000e-04
# Epoch 40/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8785 - loss: 0.2540 - val_accuracy: 0.8356 - val_loss: 0.5837 - learning_rate: 1.2500e-04
# Epoch 41/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8831 - loss: 0.2486 - val_accuracy: 0.8323 - val_loss: 0.5861 - learning_rate: 1.2500e-04
# Epoch 42/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8860 - loss: 0.2378 - val_accuracy: 0.8358 - val_loss: 0.5881 - learning_rate: 1.2500e-04
# Epoch 43/50
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8877 - loss: 0.2308
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8877 - loss: 0.2308 - val_accuracy: 0.8354 - val_loss: 0.5886 - learning_rate: 1.2500e-04
# Epoch 44/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.8903 - loss: 0.2283 - val_accuracy: 0.8338 - val_loss: 0.5862 - learning_rate: 6.2500e-05
# Epoch 45/50
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.8900 - loss: 0.2220 - val_accuracy: 0.8365 - val_loss: 0.5867 - learning_rate: 6.2500e-05
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# Evaluating on test set...
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8562 - loss: 0.4495
#
# Test Loss: 0.5842
# Test Accuracy: 0.8255 (82.55%)

# %% [markdown]
# ### Plotting Training History

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# loss
ax1.plot(history.history['loss'], label='Training Loss', linewidth=2, alpha=0.8)
ax1.plot(history.history['val_loss'], label='Validation Loss', linewidth=2, alpha=0.8)
ax1.set_title('Model Loss Over Epochs', fontsize=14, fontweight='bold')
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Loss', fontsize=12)
ax1.legend(fontsize=11)
ax1.grid(True, alpha=0.3)

# accuracy
ax2.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2, alpha=0.8)
ax2.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2, alpha=0.8)
ax2.set_title('Model Accuracy Over Epochs', fontsize=14, fontweight='bold')
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Accuracy', fontsize=12)
ax2.legend(fontsize=11)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
class_names = [f"Class {i}" for i in range(num_classes)]

num_samples = 4
random_indices = np.random.choice(len(X_test), size=num_samples, replace=False)

plt.figure(figsize=(15, 5))

for i, idx in enumerate(random_indices):
    image = X_test[idx]
    true_label = y_test[idx]

    pred_probs = model.predict(np.expand_dims(image, axis=0))
    pred_label = np.argmax(pred_probs)

    plt.subplot(1, num_samples, i+1)
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"True: {class_names[true_label]}\nPred: {class_names[pred_label]}")

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 809ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
